# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df =  pd.read_csv("clean_data.csv")

# %%
df.head()
# Out:
#                    Job Title Salary Estimate  \
# 0             Data Scientist          53-91
# 1  Healthcare Data Scientist         63-112
# 2             Data Scientist          80-90
# 3             Data Scientist          56-97
# 4             Data Scientist         86-143
#
#                                      Job Description  Rating  \
# 0  Data Scientist\r\nLocation: Albuquerque, NM\r\...     3.8
# 1  What You Will Do:\r\n\r\nI. General Summary\r\...     3.4
# 2  KnowBe4, Inc. is a high growth information sec...     4.8
# 3  *Organization and Job ID**\r\nJob ID: 310709\r...     3.8
# 4  Data Scientist\r\nAffinity Solutions / Marketi...     2.9
#
#                                 Company Name         Location  \
# 0                      Tecolote Research\r\n  Albuquerque, NM
# 1  University of Maryland Medical System\r\n    Linthicum, MD
# 2                                 KnowBe\r\n   Clearwater, FL
# 3                                   PNNL\r\n     Richland, WA
# ...

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Size', 'Founded', 'Type of ownership',
#        'Industry', 'Sector', 'Revenue', 'Age', 'min_salary', 'max_salary',
#        'average_salary', 'simplified_title', 'seniority', 'State',
#        'python_count', 'java_count', 'sql_count', 'r_count', 'spark_count',
#        'aws_count', 'excel_count'],
#       dtype='object')

# %%
df.simplified_title.value_counts()
# Out:
# data scientist    841
# na                316
# analyst           114
# mle                29
# manager            14
# director           14
# Name: simplified_title, dtype: int64

# %%
df.State
# Out:
# 0           NM
# 1           MD
# 2           FL
# 3           WA
# 4           NY
#          ...
# 1323        NY
# 1324    Remote
# 1325        MD
# 1326        TX
# 1327        NY
# Name: State, Length: 1328, dtype: object

# %%
# Job Description length
df['desc_len'] = df['Job Description'].apply(lambda x: len(x))
df['desc_len']
# Out:
# 0       2555
# 1       4828
# 2       3495
# 3       3926
# 4       2748
#         ...
# 1323    2936
# 1324    1182
# 1325    1604
# 1326    4260
# 1327    3697
# Name: desc_len, Length: 1328, dtype: int64

# %%
df.describe()
# Out:
#             Rating      Founded          Age   min_salary   max_salary  \
# count  1328.000000  1328.000000  1328.000000  1328.000000  1328.000000
# mean      3.701054  1765.160392    40.260542    82.511295   135.683735
# std       0.987624   610.780782    49.316365    23.664316    33.224490
# min      -1.000000    -1.000000     0.000000    15.000000    16.000000
# 25%       3.400000  1938.750000     9.000000    65.000000   116.000000
# 50%       3.800000  1991.000000    22.000000    81.000000   133.000000
# 75%       4.200000  2007.000000    53.000000    94.000000   153.000000
# max       5.000000  2020.000000   338.000000   202.000000   306.000000
#
#        average_salary  python_count   java_count    sql_count      r_count  \
# count     1328.000000   1328.000000  1328.000000  1328.000000  1328.000000
# mean       109.097515      0.705572     0.228163     0.571536     0.130271
# std         27.873998      0.455957     0.419806     0.495043     0.336728
# ...

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Size', 'Founded', 'Type of ownership',
#        'Industry', 'Sector', 'Revenue', 'Age', 'min_salary', 'max_salary',
#        'average_salary', 'simplified_title', 'seniority', 'State',
#        'python_count', 'java_count', 'sql_count', 'r_count', 'spark_count',
#        'aws_count', 'excel_count', 'desc_len'],
#       dtype='object')

# %%
df.Rating.hist()
# Out:
# <AxesSubplot:>

# %%
df.Revenue.hist()
# Out:
# <AxesSubplot:>

# %%
df.average_salary.hist()
# Out:
# <AxesSubplot:>

# %%
df.Age.hist()
# Out:
# <AxesSubplot:>

# %%
df.desc_len.hist()
# Out:
# <AxesSubplot:>

# %%
title_salary = df[["simplified_title", "average_salary"]]
title_salary
# Out:
#      simplified_title  average_salary
# 0      data scientist            72.0
# 1      data scientist            87.5
# 2      data scientist            85.0
# 3      data scientist            76.5
# 4      data scientist           114.5
# ...               ...             ...
# 1323   data scientist           101.5
# 1324   data scientist           101.5
# 1325   data scientist           101.5
# 1326   data scientist           101.5
# 1327          analyst           101.5
#
# [1328 rows x 2 columns]

# %%
title_salary['average_salary'].hist(by=title_salary['simplified_title'], layout=(1,6), figsize = (16,2))
# Out:
# array([<AxesSubplot:title={'center':'analyst'}>,
#        <AxesSubplot:title={'center':'data scientist'}>,
#        <AxesSubplot:title={'center':'director'}>,
#        <AxesSubplot:title={'center':'manager'}>,
#        <AxesSubplot:title={'center':'mle'}>,
#        <AxesSubplot:title={'center':'na'}>], dtype=object)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

g = sns.FacetGrid(title_salary, col = 'simplified_title')
g.map(plt.hist, "average_salary")

# %%
sns.boxplot(x = 'simplified_title', y = 'average_salary', data = title_salary)
# Out:
# <AxesSubplot:xlabel='simplified_title', ylabel='average_salary'>

# %%
sns.boxplot(x = 'simplified_title', y = 'average_salary', data = title_salary)
sns.stripplot(x = 'simplified_title', y = 'average_salary', data = title_salary,
              jitter=True, 
              marker='o',
              alpha=0.3, 
              color="black")
# Out:
# <AxesSubplot:xlabel='simplified_title', ylabel='average_salary'>

# %%
df.boxplot(column = ['Age', 'average_salary'])
# Out:
# <AxesSubplot:>

# %%
df.boxplot(column = ['Rating'])
# Out:
# <AxesSubplot:>

# %%
corr = df[['Age', 'average_salary','Rating', 'desc_len']].corr()

# %%
cmap = sns.diverging_palette(220,10,as_cmap=True)
sns.heatmap(corr,vmax=.3,center=0,cmap=cmap,square=True, linewidth=.5, cbar_kws={"shrink":.5})
# Out:
# <AxesSubplot:>

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Size', 'Founded', 'Type of ownership',
#        'Industry', 'Sector', 'Revenue', 'Age', 'min_salary', 'max_salary',
#        'average_salary', 'simplified_title', 'seniority', 'State',
#        'python_count', 'java_count', 'sql_count', 'r_count', 'spark_count',
#        'aws_count', 'excel_count', 'desc_len'],
#       dtype='object')

# %%
df_cat = df[['Location','Size','Type of ownership','Sector','Industry','Revenue','State']]

# %%
for i in df_cat.columns:
    chart = sns.barplot(x=df_cat[i].value_counts()[:20].index,y=df_cat[i].value_counts()[:20], data=df_cat)
    print("Bar Graph for %s total = %d" % (i,len(df_cat[i].value_counts()[:20])))
    chart.set_xticklabels(chart.get_xticklabels(),rotation=75,fontweight='light',
    fontsize='x-small',horizontalalignment='right')

    plt.show()
# Out:
# Bar Graph for Location total = 20
# Bar Graph for Size total = 16
# Bar Graph for Type of ownership total = 14
# Bar Graph for Sector total = 20
# Bar Graph for Industry total = 20
# Bar Graph for Revenue total = 14
# Bar Graph for State total = 20

# %%
pd.pivot_table(df,index = ["simplified_title", "seniority"], values = 'average_salary')
# Out:
#                             average_salary
# simplified_title seniority
# analyst          junior          47.166667
#                  na              79.089041
#                  senior          97.700000
# data scientist   junior         102.333333
#                  na             111.613976
#                  senior         128.000000
# director         junior         147.250000
#                  na             138.041667
# manager          na              90.076923
#                  senior          74.500000
# mle              junior         110.500000
#                  na             115.431818
#                  senior         129.916667
# na               junior          87.125000
#                  na             102.215962
#                  senior         115.873626

# %%
pd.pivot_table(df, index = ['State','simplified_title'], values = 'average_salary').sort_values('State',ascending=False)
# Out:
#                          average_salary
# State  simplified_title
# Remote na                    100.214286
#        mle                    74.500000
#        data scientist        113.650000
#        analyst               101.500000
# IL     analyst               151.000000
# ...                                 ...
#  AR    data scientist         74.500000
#  AL    data scientist         97.500000
#        analyst                66.000000
#        na                     50.833333
#  AK    na                    147.500000
#
# [125 rows x 1 columns]

# %%
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
from geopy.geocoders import Nominatim
import math
import cartopy.feature as cfeature

ax.set_extent([-135, -66.5, 20, 55],
              crs=ccrs.PlateCarree()) ## Important

# %%
##This was necessary to first grab our data, but we have created a csv to shorten data retrieval time, 
## uncomment if you lose access to coordinates
# geolocator = Nominatim(user_agent="ds_salary_proj")

# geocode = RateLimiter(geolocator.geocode, min_delay_seconds=1)


# from geopy.extra.rate_limiter import RateLimiter
# from tqdm import tqdm
# tqdm.pandas()

# def eval_results(x):
#     try:
#         return (x.latitude, x.longitude)
#     except:
#         return (-1, -1)

# loc = df['Location'].progress_apply(geolocator.geocode, timeout=1000000).apply(lambda x: eval_results(x))

coordinates = pd.DataFrame.from_records(loc, columns=['longitude', 'latitude'])
coordinates.to_csv("coordinates.csv", index = False)
pd.read_csv("coordinates.csv")
# Out:
#       longitude    latitude
# 0     35.084103 -106.650985
# 1     39.203909  -76.659709
# 2     27.965853  -82.800103
# 3     46.280430 -119.275205
# 4     40.712728  -74.006015
# ...         ...         ...
# 1323  40.712728  -74.006015
# 1324  43.005946 -123.892591
# 1325  39.267328  -76.798307
# 1326  32.829518  -96.944218
# 1327  43.157285  -77.615214
#
# [1328 rows x 2 columns]

# %%
import numpy as np



fig = plt.figure(figsize=(12,10))

ax = fig.add_subplot(1,1,1, projection=crs.PlateCarree())

ax.coastlines()
ax.add_feature(cfeature.STATES)

ax.set_extent([-135, -66.5, 20, 55], crs=crs.PlateCarree()) ## Important
df_range = len(loc)
color = df['average_salary'].div((df_range*100))
plt.scatter(coordinates.latitude,coordinates.longitude,alpha = 0.6, c= color, cmap="bwr_r")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
# C:\ProgramData\Anaconda3\lib\site-packages\cartopy\mpl\geoaxes.py:388: MatplotlibDeprecationWarning:
# The 'inframe' parameter of draw() was deprecated in Matplotlib 3.3 and will be removed two minor releases later. Use Axes.redraw_in_frame() instead. If any parameter follows 'inframe', they should be passed as keyword, not positionally.
#   inframe=inframe)

# %%
pd.pivot_table(df, index = ['State','simplified_title'], 
               values='average_salary', aggfunc = 'count').sort_values('State',ascending=False)
# Out:
#                          average_salary
# State  simplified_title
# Remote na                             7
#        mle                            2
#        data scientist                20
#        analyst                        1
# IL     analyst                        1
# ...                                 ...
#  AR    data scientist                 1
#  AL    data scientist                 3
#        analyst                        4
#        na                             3
#  AK    na                             1
#
# [125 rows x 1 columns]

# %%
salary_pivot = pd.pivot_table(df[df.simplified_title == 'data scientist'], index = 'State', 
               values ='average_salary', aggfunc=[np.mean,'count'])
salary_pivot.sort_values(by=( 'mean', 'average_salary'),ascending=False)
# Out:
#                  mean          count
#        average_salary average_salary
# State
#  MN        129.333333              6
#  WI        123.583333              6
#  NJ        118.590909             11
#  CA        117.569915            236
#  DC        116.040000             25
#  MD        115.745455             55
#  GA        115.727273             11
#  MO        115.307692             13
#  VA        114.578571             70
#  NH        113.833333              3
# Remote     113.650000             20
#  MA        113.426667             75
#  IL        113.212121             33
#  CO        112.928571             14
#  NC        112.694444             18
#  NY        111.373333             75
#  TX        111.083333             42
#  OH        110.833333             12
#  KS        110.500000              1
#  UT        110.388889              9
#  MI        109.500000              4
#  PA        108.823529             17
#  WA        107.075758             33
# ...

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Size', 'Founded', 'Type of ownership',
#        'Industry', 'Sector', 'Revenue', 'Age', 'min_salary', 'max_salary',
#        'average_salary', 'simplified_title', 'seniority', 'State',
#        'python_count', 'java_count', 'sql_count', 'r_count', 'spark_count',
#        'aws_count', 'excel_count', 'desc_len'],
#       dtype='object')

# %%
# Rating, Industry, Revenue, Python, Java, SQL, Spark, AWS, Excel

# %%
df_pivots = df[['Rating', 'Industry','Sector', 'Revenue', 'python_count','r_count','java_count', 'sql_count', 'spark_count', 'aws_count', 'excel_count', 'Type of ownership', 'average_salary' ]]

# %%
for i in df_pivots[df_pivots.columns[:-1]]:
    print(i)
    print(pd.pivot_table(df_pivots, index= i, values = 'average_salary').sort_values('average_salary', ascending=False))
# Out:
# Rating
#         average_salary
# Rating
#  4.5        115.364865
#  4.1        114.983051
#  4.0        114.936893
#  1.4        114.000000
#  4.2        111.858333
#  3.5        111.614286
#  3.3        111.491228
#  4.4        111.250000
#  3.9        111.060000
#  4.7        110.090909
#  2.5        110.000000
#  5.0        109.538462
#  4.6        109.533333
#  3.7        109.323529
#  3.8        109.210526
#  2.6        108.750000
#  3.2        108.521277
# -1.0        108.052632
#  4.8        107.900000
#  3.6        107.895604
#  2.0        107.666667
#  4.9        106.611111
#  1.8        105.500000
#  4.3        104.769231
#  2.9        103.596774
#  2.7        103.166667
#  3.4        102.448276
#  2.2         97.750000
#  3.0         97.000000
#  3.1         96.287879
#  2.8         94.500000
#  2.1         92.000000
#  1.9         87.500000
#  2.3         81.500000
#  2.4         61.500000
# Industry
#                                average_salary
# Industry
# ...

# %%
pd.pivot_table(df_pivots, index= 'Revenue', columns = 'python_count', values= 'average_salary', aggfunc = 'count')
# Out:
# python_count                       0    1
# Revenue
# $1 to $2 billion (USD)            21   66
# $1 to $5 million (USD)             3   29
# $10 to $25 million (USD)          17   38
# $10+ billion (USD)                65  149
# $100 to $500 million (USD)        50   91
# $2 to $5 billion (USD)            17   46
# $25 to $50 million (USD)          25   56
# $5 to $10 billion (USD)           19   37
# $5 to $10 million (USD)           14   18
# $50 to $100 million (USD)         21   44
# $500 million to $1 billion (USD)  32   37
# -1                                 4   15
# Less than $1 million (USD)        20   63
# Unknown / Non-Applicable          83  248

# %%
from wordcloud import WordCloud, ImageColorGenerator, STOPWORDS
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import nltk
from nltk.corpus import stopwords

# %%
words = " ".join(df['Job Description'])

def punctuation_stop(text):
    """remove punctuation and stop words"""
    filtered = []
    stop_words = set(stopwords.words('english'))
    word_tokens = word_tokenize(text)
    for w in word_tokens:
        if w not in stop_words and w.isalpha():
            filtered.append(w.lower())
    return filtered


words_filtered = punctuation_stop(words)

text = " ".join([ele for ele in words_filtered])

# %%
wc= WordCloud(background_color="white", random_state=1,stopwords=STOPWORDS, max_words = 2000, width =800, height = 1500)
wc.generate(text)

# %%
plt.figure(figsize=[10,10])
plt.imshow(wc, interpolation="bilinear")
plt.axis('off')
plt.show()

# %%
df.to_csv("explored_data")

# %%
q
